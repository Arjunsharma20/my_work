# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
#  1.ipynb
# 'Apple Stocks.ipynb'
#  BGMI_Prediction.ipynb
# 'Building SVM Classifier from Scratch in Python.ipynb'
# 'Copy of Untitled4.ipynb'
# 'DA project 3.ipynb'
# 'Data Analysis project 1.ipynb'
# 'Data Analysis Project 2.ipynb'
# 'Data Analytic Project.ipynb'
# 'Data Preprocessing (1).ipynb'
# 'Data Preprocessing.ipynb'
# 'Data Standardization.ipynb'
# 'E-Commerce Analysis Project.ipynb'
# 'E-Commerce Sales Project.ipynb'
# 'End to End Toy Project.ipynb'
# 'Handling Missing Value 2.ipynb'
# 'Handling Missing Value 3.ipynb'
# 'Handling Missing Value.ipynb'
# 'Improve Dataset through Kaggle API.ipynb'
#  labelencoder.ipynb
# 'Linear Regression from scratches .ipynb'
#  Loan_Approval.ipynb
#  Loan_Approval_Prediction.ipynb
#  LoanApprovalPrediction.ipynb
# 'Logistic Regression from Scratch Using Python.ipynb'
#  matplotlib.ipynb
#  Matrix.ipynb
# 'Matrix part 2.ipynb'
#  Medicine_Recommendation_System.ipynb
#  MultipleLinearRegressionByDirectFormula.ipynb
#  Numpy.ipynb
# ...

# %%
# !git clone https://github.com/your-username/my_work.git
# %cd my_work
# Out:
# fatal: destination path 'my_work' already exists and is not an empty directory.
# /content/my_work

# %%
# !cp -r "/content/drive/My Drive/Colab Notebooks" ./python

# %%
# !git config --global user.name "ArjunSharma"
# !git config --global user.email "arjunsharma132620.com"

# %%
# !git remote set-url origin https://arjun_s020@github.com/ArjunSharma/my_work.git

# %%
import os
os.environ['GITHUB_TOKEN'] = "<arjun_s020>"

# %%
# !git remote set-url origin https://${GITHUB_TOKEN}@github.com/arjun-s020/my_work.git

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://%3Carjun_s020%3E@github.com': No such device or address
