# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["harry","arjun","golu"],
    "marks":[34,55,33],
    "city":["kolkata","jagadhri","yammunanagar"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False)

# %%
df.head(2)

# %%
df.tail(2)

# %%
df.describe()

# %%
a=[1,2,3,4,5]

# %%
ser=pd.Series(a)

# %%
type(ser)
newdf.head(6)

# %%
ser

# %%
newdf = pd.DataFrame(np.random.rand(334,6),index=np.arange(334))

# %%
newdf

# %%
newdf.to_csv('Data.csv')

# %%
newdf.describe()

# %%
newdf[0][0]="Arjun"

# %%
newdf.dtypes

# %%
newdf.index

# %%
newdf.columns

# %%
newdf.to_numpy()

# %%
newdf[0][0]=0.132425433

# %%
newdf.T

# %%
newdf[0]

# %%
newdf.head()

# %%
newdf.sort_index(axis=1,ascending=False)

# %%
newdf2.index[0][0
