# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 494          495         0       3
# 879          880         1       1
# 643          644         1       3
# 782          783         0       1
# 584          585         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 494                     Stanley, Mr. Edward Roland    male  21.0      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 643                                Foo, Mr. Choong    male   NaN      0
# 782                         Long, Mr. Milton Clyde    male  29.0      0
# 584                            Paulner, Mr. Uscher    male   NaN      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 494      0  A/4 45380   8.0500   NaN        S
# 879      1      11767  83.1583   C50        C
# 643      0       1601  56.4958   NaN        S
# 782      0     113501  30.0000    D6        S
# 584      0       3411   8.7125   NaN        C

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 789          790         0       1
# 46            47         0       3
# 513          514         1       1
# 34            35         0       1
# 153          154         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 789                        Guggenheim, Mr. Benjamin    male  46.0      0
# 46                                Lennon, Mr. Denis    male   NaN      1
# 513  Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 34                          Meyer, Mr. Edgar Joseph    male  28.0      1
# 153                 van Billiard, Mr. Austin Blyler    male  40.5      0
#
#      Parch    Ticket     Fare    Cabin Embarked
# 789      0  PC 17593  79.2000  B82 B84        C
# 46       0    370371  15.5000      NaN        Q
# 513      0  PC 17603  59.4000      NaN        C
# 34       0  PC 17604  82.1708      NaN        C
# 153      2  A/5. 851  14.5000      NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df= df.drop('Cabin' ,axis =1)

# %%
df.shape
# Out:
# (891, 11)

# %%
df['Age'].fillna(df['Age'].mean(), inplace=False)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
from sklearn.model_selection import train_test_split

# %%
X_test,X_train,Y_test,Y_train = train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (179, 10)

# %%
X_test.shape
# Out:
# (712, 10)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

# %%
transforms = ColumnTransformer(transformers=[
    ('t1',SimpleImputer(),['Age']),
    ('t2', OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),['Sex','Embarked']),
    ('t3',MinMaxScaler(),['Fare','Age'])
],remainder='passthrough')

# %%
transforms.fit_transform(X_train).shape
# Out:
# (179, 12)

# %%
transforms.transform(X_test).shape
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# (712, 12)

# %%
df.drop(columns=['Name','Ticket','PassengerId'],inplace=True)

# %%
df.sample(5)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Fare Embarked
# 292         0       2    male  36.0      0      0  12.875        C
# 330         1       3  female   NaN      2      0  23.250        Q
# 726         1       2  female  30.0      3      0  21.000        S
# 497         0       3    male   NaN      0      0  15.100        S
# 415         0       3  female   NaN      0      0   8.050        S

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.2,random_state=42)

# %%
X_train.head(2)
# Out:
#      Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 331       1  male  45.5      0      0  28.5        S
# 733       2  male  23.0      0      0  13.0        S

# %%
Y_train.head(2)
# Out:
# 331    0
# 733    0
# Name: Survived, dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
from re import X
s1_age= SimpleImputer()
s1_embarked=SimpleImputer(strategy='most_frequent')
X_train_age=s1_age.fit_transform(X_train[['Age']])
X_train_embarked=s1_embarked.fit_transform(X_train[['Embarked']])

# %%
ohe_sex = OneHotEncoder(sparse_output=False,handle_unknown='ignore')
ohe_embarked = OneHotEncoder(sparse_output=False,handle_unknown='ignore')

X_train_sex = ohe_sex.fit_transform(X_train[['Sex']])
X_train_embarked = ohe_embarked.fit_transform(X_train_embarked)

# %%
X_train_rem = X_train.drop(columns=['Sex','Age','Embarked'])

# %%
X_train_transform = np.concatenate((X_train_rem,X_train_age,X_train_sex,X_train_embarked),axis=1)

# %%
X_train_transform.shape
# Out:
# (712, 10)

# %%
from sklearn.metrics import accuracy_score

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train_transform,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = clf.predict(X_train_transform)
accuracy_score(Y_train,Y_pred)
# Out:
# 0.9803370786516854

# %% [markdown]
# Log Transform and QQ plot

# %%
import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv',usecols=['Survived','Age','Fare'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace= True)
# Out:
# /tmp/ipython-input-46-946940163.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace= True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
X = df.iloc[:,1:3]
Y = df.iloc[:,0]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train['Age'])
plt.subplot(122)
stats.probplot(X_train['Age'],plot=plt)
plt.show()
# Out:
# /tmp/ipython-input-50-2464761883.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'])

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train['Fare'])
plt.subplot(122)
stats.probplot(X_train['Fare'],plot=plt,dist='norm')
plt.show()
# Out:
# /tmp/ipython-input-51-3718949790.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Fare'])

# %%
clf = LogisticRegression()
clf1 = DecisionTreeClassifier()

# %%
clf.fit(X_train,Y_train)
clf1.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)
y_pred1 = clf1.predict(X_test)

# %%
print("Accuracy score LR :",accuracy_score(Y_test,y_pred))
print("Accuracy score DT :",accuracy_score(Y_test,y_pred1))
# Out:
# Accuracy score LR : 0.6480446927374302
# Accuracy score DT : 0.6759776536312849

# %%
trf = FunctionTransformer(func=np.log1p)

# %%
X_train_transform = trf.fit_transform(X_train)
X_test_transform = trf.transform(X_test)

# %%
clf = LogisticRegression()
clf1 = DecisionTreeClassifier()

# %%
clf.fit(X_train_transform,Y_train)
clf1.fit(X_train_transform,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = clf.predict(X_test_transform)
Y_pred1 = clf1.predict(X_test_transform)

# %%
print("Accuracy score LR :",accuracy_score(Y_test,Y_pred))
print("Accuracy score DT :",accuracy_score(Y_test,Y_pred1))
# Out:
# Accuracy score LR : 0.6815642458100558
# Accuracy score DT : 0.664804469273743

# %%
plt.subplot(121)

stats.probplot(X_train['Fare'],plot=plt,dist='norm')
plt.title('fare before Transformation')


plt.subplot(122)

stats.probplot(X_test_transform['Fare'],plot=plt,dist='norm')
plt.title('fare after Transformation')
plt.show()

# %%
plt.subplot(121)
stats.probplot(X_train['Age'],plot=plt,dist='norm')
plt.title('fare before Transformation')


plt.subplot(122)

stats.probplot(X_test_transform['Age'],plot=plt,dist='norm')
plt.title('fare after Transformation')
plt.show()

# %%
trf = ColumnTransformer([('log', FunctionTransformer(np.log1p),['Fare'])],remainder='passthrough')
X_test_transform2 = trf.fit_transform(X_test)
X_train_transform2 = trf.transform(X_train)

# %%
clf = LogisticRegression()
clf1 = DecisionTreeClassifier()

# %%
clf.fit(X_train_transform2,Y_train)
clf1.fit(X_train_transform2,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = clf.predict(X_test_transform2)
Y_pred1 = clf1.predict(X_test_transform2)

# %%
print("Accuracy score LR :",accuracy_score(Y_test,Y_pred))
print("Accuracy score DT :",accuracy_score(Y_test,Y_pred1))
# Out:
# Accuracy score LR : 0.6703910614525139
# Accuracy score DT : 0.659217877094972

# %%
print("LR" ,np.mean(cross_val_score(clf,X_train_transform2,Y_train,cv=10,scoring='accuracy')))
print("DT" ,np.mean(cross_val_score(clf1,X_train_transform2,Y_train,cv=10,scoring='accuracy')))
# Out:
# LR 0.6572378716744913
# DT 0.6320031298904538

# %% [markdown]
# Binning

# %%
import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import KBinsDiscretizer

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv',usecols=['Survived','Age','Fare'])

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-73-694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
X = df.iloc[:,1:3]
Y = df.iloc[:,0]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
 Y_pred  =clf.predict(X_test)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.664804469273743

# %%
kbin_age = KBinsDiscretizer(n_bins=15,strategy='quantile',encode='ordinal')
kbin_fare = KBinsDiscretizer(n_bins=15,strategy='quantile',encode='ordinal')

# %%
trf = ColumnTransformer([
    ('first',kbin_age,['Age']),
    ('second',kbin_fare,['Fare'])
],remainder='passthrough')

# %%
X_train_trf = trf.fit_transform(X_train)
X_test_trf = trf.transform(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_discretization.py:306: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(

# %%
trf.named_transformers_['first'].bin_edges_
# Out:
# array([array([ 0.42      ,  8.4       , 18.        , 21.        , 23.        ,
#               25.        , 28.        , 29.69911765, 31.        , 34.        ,
#               38.        , 44.        , 51.        , 80.        ])            ],
#       dtype=object)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train_trf,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = clf.predict(X_test_trf)

# %%
accuracy_score(Y_test,y_pred2)
# Out:
# 0.6312849162011173

# %% [markdown]
# Handling Missing value

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]

# %%
print(cols)
# Out:
# ['Embarked']

# %%
df[cols].sample(5)
# Out:
#     Embarked
# 383        S
# 863        S
# 521        S
# 250        S
# 767        Q

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.9977553310886644

# %%
new_df = df[cols].dropna()
df.shape, new_df.shape
# Out:
# ((891, 12), (889, 1))

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
temp = pd.concat([
    df['Embarked'].value_counts()/len(df),
    new_df['Embarked'].value_counts()/len(new_df)

],
                  axis=1)
temp.columns =['Original','CCA']
temp
# Out:
#           Original       CCA
# Embarked
# S         0.722783  0.724409
# C         0.188552  0.188976
# Q         0.086420  0.086614

# %%
X = df.drop(columns =['Survived'])
Y = df['Survived']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((712, 11), (179, 11))

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

# %%
X_train['Age_mean'] = X_train['Age'].fillna(mean_age)
X_train['Age_median'] = X_train['Age'].fillna(median_age)

# %%
X_train.sample(5)
# Out:
#      PassengerId  Pclass                              Name     Sex   Age  \
# 191          192       2             Carbines, Mr. William    male  19.0
# 214          215       3               Kiernan, Mr. Philip    male   NaN
# 537          538       1               LeRoy, Miss. Bertha  female  30.0
# 156          157       3  Gilnagh, Miss. Katherine "Katie"  female  16.0
# 71            72       3        Goodwin, Miss. Lillian Amy  female  16.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked   Age_mean  Age_median
# 191      0      0     28424   13.0000   NaN        S  19.000000        19.0
# 214      1      0    367229    7.7500   NaN        Q  29.498846        28.0
# 537      0      0  PC 17761  106.4250   NaN        C  30.000000        30.0
# 156      0      0     35851    7.7333   NaN        Q  16.000000        16.0
# 71       5      2   CA 2144   46.9000   NaN        S  16.000000        16.0

# %%
print("Original ge variable variance:",X_train['Age'].var())
print("Age variance after mean:",X_train['Age_mean'].var())
print("Age variance after median:",X_train['Age_median'].var())
# Out:
# Original ge variable variance: 210.2517072477438
# Age variance after mean: 168.8519336687225
# Age variance after median: 169.20731007048096

# %%
X_train_num = X_train.select_dtypes(include=['int64','float64'])
# X_train_num.sample(5)
X_train_num.cov()
# Out:
#               PassengerId     Pclass         Age      SibSp     Parch  \
# PassengerId  65911.023671  -9.775133  122.284714 -20.907754 -0.044063
# Pclass          -9.775133   0.679939   -4.288674   0.084329  0.008277
# Age            122.284714  -4.288674  210.251707  -4.501273 -2.492052
# SibSp          -20.907754   0.084329   -4.501273   1.383927  0.410112
# Parch           -0.044063   0.008277   -2.492052   0.410112  0.626740
# Fare           340.450549 -23.431910   71.580633   9.354652  9.141094
# Age_mean        98.206149  -3.444209  210.251707  -3.614946 -2.001353
# Age_median     102.238566  -3.536527  210.251707  -3.637141 -1.950569
#
#                     Fare    Age_mean  Age_median
# PassengerId   340.450549   98.206149  102.238566
# Pclass        -23.431910   -3.444209   -3.536527
# Age            71.580633  210.251707  210.251707
# SibSp           9.354652   -3.614946   -3.637141
# Parch           9.141094   -2.001353   -1.950569
# ...

# %%
X_train[['Age','Age_mean','Age_median']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Using sklearn

# %%
imputer1 = SimpleImputer(strategy='mean')
imputer2 = SimpleImputer(strategy='median')

# %%
trf = ColumnTransformer([
    ('mean_age',imputer1,['Age']),
    ('median_age',imputer2,['Age'])
],remainder='passthrough')

# %%
trf.fit_transform(X_train)
# Out:
# array([[45.5, 45.5, 332, ..., 'S', 45.5, 45.5],
#        [23.0, 23.0, 734, ..., 'S', 23.0, 23.0],
#        [32.0, 32.0, 383, ..., 'S', 32.0, 32.0],
#        ...,
#        [41.0, 41.0, 861, ..., 'S', 41.0, 41.0],
#        [14.0, 14.0, 436, ..., 'S', 14.0, 14.0],
#        [21.0, 21.0, 103, ..., 'S', 21.0, 21.0]], dtype=object)

# %%
trf.named_transformers_['mean_age'].statistics_
# Out:
# array([29.49884615])

# %%
trf.named_transformers_['median_age'].statistics_
# Out:
# array([28.])

# %%
X_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            140
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          553
# Embarked         2
# Age_mean         0
# Age_median       0
# dtype: int64

# %%
X_train['Age'].isnull().sum()
# Out:
# np.int64(140)

# %%
# Create the 'Age_Imputed' column by copying the 'Age' column
X_train['Age_Imputed'] = X_train['Age'].copy()
X_test['Age_Imputed'] = X_test['Age'].copy()

# Now you can fill the missing values in the newly created 'Age_Imputed' columns
X_train['Age_Imputed'][X_train['Age_Imputed'].isnull()]= X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_Imputed'][X_test['Age_Imputed'].isnull()]= X_test['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# /tmp/ipython-input-112-1266666222.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_train['Age_Imputed'][X_train['Age_Imputed'].isnull()]= X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# ...

# %%
X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# Out:
# array([28.  , 44.  , 27.  , 18.  , 40.  ,  4.  , 31.  , 19.  , 21.  ,
#        44.  , 25.  , 30.  , 52.  , 47.  , 24.  , 25.  , 44.  ,  1.  ,
#        35.  , 28.  , 22.  , 45.  ,  1.  , 60.  , 18.  , 39.  , 54.  ,
#        20.  , 34.  , 40.  , 47.  , 38.  , 24.  , 37.  , 22.  , 22.  ,
#        20.  ,  7.  , 33.  , 54.  , 25.  , 16.  , 29.  , 31.  , 29.  ,
#        17.  , 59.  , 30.  , 16.  , 16.  , 33.  , 45.  , 21.  , 65.  ,
#        26.  , 38.  , 30.  ,  5.  , 35.  , 39.  , 24.  , 15.  , 18.  ,
#        32.  , 17.  , 21.  , 30.  , 28.  , 34.  , 43.  , 32.  , 25.  ,
#        28.  , 31.  , 42.  , 33.  , 36.  , 24.  ,  2.  , 27.  , 37.  ,
#        14.  , 25.  , 39.  , 45.  , 35.  , 33.  , 52.  , 22.  , 46.  ,
#        26.  , 42.  , 24.  , 20.  , 18.  , 29.  , 54.  , 45.  ,  7.  ,
#        34.  , 52.  , 12.  , 48.  , 35.  , 43.  , 15.  , 25.  , 33.  ,
#        39.  , 19.  , 15.  , 40.  , 35.  , 33.  , 34.  , 26.  , 18.  ,
# ...

# %%
sns.distplot(X_train['Age'],label="original",hist=False)
sns.distplot(X_train['Age_Imputed'],label="imputed",hist=False)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-114-1903930327.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'],label="original",hist=False)
# /tmp/ipython-input-114-1903930327.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df=pd.read_csv('/content/Titanic-Dataset.csv')[['Age','Pclass','Fare','Survived']]

# %%
X = df.drop(columns=['Survived'])
Y = df['Survived']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=5)
X_train_trf = knn.fit_transform(X_train)
X_test_trf = knn.transform(X_test)
pd.DataFrame(X_train_trf,columns=X_train.columns)
# Out:
#       Age  Pclass      Fare
# 0    45.5     1.0   28.5000
# 1    23.0     2.0   13.0000
# 2    32.0     3.0    7.9250
# 3    26.0     3.0    7.8542
# 4     6.0     3.0   31.2750
# ..    ...     ...       ...
# 707  21.0     3.0    7.6500
# 708  39.0     1.0   31.0000
# 709  41.0     3.0   14.1083
# 710  14.0     1.0  120.0000
# 711  21.0     1.0   77.2875
#
# [712 rows x 3 columns]

# %%
lr = LogisticRegression()
lr.fit(X_train_trf,Y_train)
y_pred = lr.predict(X_test_trf)
accuracy_score(Y_test,y_pred)
# Out:
# 0.7430167597765364

# %%
si = SimpleImputer()
X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
lr = LogisticRegression()
lr.fit(X_train_trf2,Y_train)
y_pred2 = lr.predict(X_test_trf2)
accuracy_score(Y_test,y_pred2)
# Out:
# 0.7374301675977654

# %% [markdown]
# Outlier handling

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.637899
# std       14.343017
# min        1.000000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       65.870000
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].skew()
# Out:
# np.float64(0.34935689679691867)

# %%
sns.boxenplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
lower = df['Age'].quantile(0.01)
upper = df['Age'].quantile(0.99)

# %%
df_new = df[(df['Age']<upper) & (df['Age']>lower)]
df_new
# Out:
#            Age  Pclass     Fare  Survived
# 0    22.000000       3   7.2500         0
# 1    38.000000       1  71.2833         1
# 2    26.000000       3   7.9250         1
# 3    35.000000       1  53.1000         1
# 4    35.000000       3   8.0500         0
# ..         ...     ...      ...       ...
# 886  27.000000       2  13.0000         0
# 887  19.000000       1  30.0000         1
# 888  29.637899       3  23.4500         0
# 889  26.000000       1  30.0000         1
# 890  32.000000       3   7.7500         0
#
# [866 rows x 4 columns]

# %%
df['Age'] = np.where(
    df['Age']>upper,
    upper,
    np.where(
        df['Age']<lower,
        lower,
        df['Age']
    )
)

# %%
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.637899
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.630088
# std       12.815963
# min        1.000000
# 25%       22.000000
# 50%       29.637899
# 75%       35.000000
# max       65.000000
# Name: Age, dtype: float64
