# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds= pd.read_csv("/content/TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# <ipython-input-3-6097979e9819>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds= pd.read_csv("/content/TWO_CENTURIES_OF_UM_RACES.csv")

# %%
ds.head(2)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
#
#   Athlete average speed  Athlete ID
# 0                10.286         0.0
# 1                 9.501         1.0

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6588165 entries, 0 to 6588164
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 653.4+ MB

# %%
ds.isnull().sum()
# Out:
# Year of event                      0
# Event dates                        0
# Event name                         0
# Event distance/length            910
# Event number of finishers          0
# Athlete performance                2
# Athlete club                 2484997
# Athlete country                    4
# Athlete year of birth         482641
# Athlete gender                     5
# Athlete age category          479638
# Athlete average speed            216
# Athlete ID                         1
# dtype: int64

# %%
ds["Year of event"].unique()
# Out:
# array([2018, 2016, 2017, 2019, 2020, 2021, 2022, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015])

# %%
ds["Year of event"].unique()
# Out:
# array([2018, 2016, 2017, 2019, 2020, 2021, 2022, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015])

# %%
ds.shape
# Out:
# (6588165, 13)

# %%
ds.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %%
ds[(ds["Event distance/length"].isin(['50km','50mi'])) & (ds["Year of event"] ==2018)]
# Out:
#         Year of event     Event dates                 Event name  \
# 0                2018      06.01.2018        Selva Costera (CHI)
# 1                2018      06.01.2018        Selva Costera (CHI)
# 2                2018      06.01.2018        Selva Costera (CHI)
# 3                2018      06.01.2018        Selva Costera (CHI)
# 4                2018      06.01.2018        Selva Costera (CHI)
# ...               ...             ...                        ...
# 661478           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661479           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661480           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661481           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
# 661482           2018  27.-28.10.2018  Cactus Rose 50 Mile (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 0                       50km                         22           4:51:39 h
# ...

# %%
ds[ds['Event name']=='Selva Costera (CHI)']["Event name"].str.split('').str.get(-1)
# Out:
# 0
# 1
# 2
# 3
# 4
#           ..
# 2567375
# 2567376
# 2567377
# 2567378
# 2567379
# Name: Event name, Length: 82, dtype: object

# %%
ds[ds['Event name'].str.split().str.get(-1).str.split().str.get(0)=='(USA)']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 6587875           2015  12.07.2015
# 6587876           2015  12.07.2015
# 6587877           2015  12.07.2015
# 6587878           2015  12.07.2015
# 6587879           2015  12.07.2015
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
ds['Event country']=ds['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)

# %%
ds.head(2)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
#
#   Athlete average speed  Athlete ID Event country
# 0                10.286         0.0           CHI
# 1                 9.501         1.0           CHI

# %%
# ds2=ds[(ds["Event distance/length"].isin(['50km','50mi'])) & (ds["Year of event"] ==2018)] & (ds['Event name'].str.split().str.get(-1).str.split().str.get(0)=='(USA)')

# %%
ds['athlete_age']=2018-ds['Athlete year of birth']

# %%
ds['Athlete performance']=ds['Athlete performance'].str.split().str.get(0)

# %%
ds.head(2)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22                 nan               Tnfrc
# 1                         22                 nan  Roberto Echeverría
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
#
#   Athlete average speed  Athlete ID Event country  athlete_age
# 0                10.286         0.0           CHI         40.0
# 1                 9.501         1.0           CHI         37.0

# %%
ds.drop(["Athlete club","Athlete year of birth","Athlete age category"],axis=1,inplace=True)

# %%
ds.head(2)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance Athlete country  \
# 0                         22                 nan             CHI
# 1                         22                 nan             CHI
#
#   Athlete gender Athlete average speed  Athlete ID Event country  athlete_age
# 0              M                10.286         0.0           CHI         40.0
# 1              M                 9.501         1.0           CHI         37.0

# %%
ds.dropna(inplace=True)

# %%
ds.isnull().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete country              0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# Event country                0
# athlete_age                  0
# dtype: int64

# %%
ds[ds.duplicated()==True]
# Out:
#          Year of event            Event dates  \
# 476215            2018             18.08.2018
# 577695            2018  31.12.2018-01.01.2019
# 577697            2018  31.12.2018-01.01.2019
# 970871            2016         17.-18.08.2016
# 970872            2016         17.-18.08.2016
# 1116779           2016  28.12.2016-03.01.2017
# 1116780           2016  28.12.2016-03.01.2017
# 1116822           2016  28.12.2016-03.01.2017
# 1204313           2017             18.02.2017
# 1447945           2017             21.07.2017
# 1694882           2017             30.09.2017
# 1853512           2019             26.01.2019
# 2463133           2019  28.12.2019-03.01.2020
# 3848692           2000             16.06.2000
# 3855114           2000             16.06.2000
# 4021124           2002             16.03.2002
# 4184416           2004             10.04.2004
# 4362780           2006             16.06.2006
# 4485080           2007         21.-22.07.2007
# ...

# %%
ds.reset_index(drop=True,inplace=True)

# %%
ds.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance Athlete country  \
# 0                         22                 nan             CHI
# 1                         22                 nan             CHI
# 2                         22                 nan             CHI
# 3                         22                 nan             ARG
# 4                         22                 nan             CHI
#
#   Athlete gender Athlete average speed  Athlete ID Event country  athlete_age
# ...

# %%
ds.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# Event country                 object
# athlete_age                  float64
# dtype: object

# %%
ds['athlete_age']=ds['athlete_age'].astype(int)

# %%
ds.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# Event country                 object
# athlete_age                    int64
# dtype: object

# %%
ds=ds.rename(columns={'Year of event':'Year',
                      'Event dates':'Event_day',
                      'Event name':'Event_name',
                      'Event number of finishers':'Race_number_of_finishers',
                      'Event distance/length':'Race_length',
                      'Event performance':'Race_performance',
                      })

# %%
ds.head()
# Out:
#    year   event_day           event_name race_length  \
# 0  2018  06.01.2018  Selva Costera (CHI)        50km
# 1  2018  06.01.2018  Selva Costera (CHI)        50km
# 2  2018  06.01.2018  Selva Costera (CHI)        50km
# 3  2018  06.01.2018  Selva Costera (CHI)        50km
# 4  2018  06.01.2018  Selva Costera (CHI)        50km
#
#    race_number_of_finishers Athlete performance Athlete country  \
# 0                        22                 nan             CHI
# 1                        22                 nan             CHI
# 2                        22                 nan             CHI
# 3                        22                 nan             ARG
# 4                        22                 nan             CHI
#
#   Athlete gender Athlete average speed  Athlete ID Event country  athlete_age
# 0              M                10.286         0.0           CHI           40
# 1              M                 9.501         1.0           CHI           37
# ...

# %%
ds[ds['event_name']=='Yankee Springs 50 km Winter Challenge (USA)']
# Out:
#          year   event_day                                   event_name  \
# 59       2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 60       2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 61       2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 62       2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 63       2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# ...       ...         ...                                          ...
# 5968839  2015  03.01.2015  Yankee Springs 50 km Winter Challenge (USA)
# 5968840  2015  03.01.2015  Yankee Springs 50 km Winter Challenge (USA)
# 5968841  2015  03.01.2015  Yankee Springs 50 km Winter Challenge (USA)
# 5968842  2015  03.01.2015  Yankee Springs 50 km Winter Challenge (USA)
# 5968843  2015  03.01.2015  Yankee Springs 50 km Winter Challenge (USA)
#
#         race_length  race_number_of_finishers Athlete performance  \
# ...

# %%
ds[ds['Athlete ID']==222509]
# Out:
#          year   event_day                                    event_name  \
# 305199   2018  28.07.2018  Minnesota Voyageur Trail 50 Mile Ultra (USA)
# 2410286  2020  14.03.2020            Everglades 50 Mile Ultra Run (USA)
# 2432911  2020  22.02.2020                 Manasota Track Club 50K (USA)
#
#         race_length  race_number_of_finishers Athlete performance  \
# 305199         50mi                       346                 nan
# 2410286        50mi                        40                 nan
# 2432911        50km                        36                 nan
#
#         Athlete country Athlete gender Athlete average speed  Athlete ID  \
# 305199              USA              M                 5.917    222509.0
# 2410286             USA              M                 8.634    222509.0
# 2432911             USA              M                10.371    222509.0
#
#         Event country  athlete_age
# 305199            USA           21
# 2410286           USA           21
# ...

# %%
ds2=ds[(ds["race_length"].isin(['50km','50mi'])) & (ds["year"] ==2018)]

# %%
sns.histplot(ds2['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(ds2,x='race_length',hue='Athlete gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
ds2['Athlete average speed'] = ds2['Athlete average speed'].astype(str)
sns.violinplot(data=ds2,x="race_length" , y="Athlete average speed", hue='Athlete gender')
plt.show()
# Out:
# <ipython-input-84-eba518c824cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds2['Athlete average speed'] = ds2['Athlete average speed'].astype(str)
